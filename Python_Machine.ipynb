# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import plotly.graph_objs as go

# %%
# Read the machinedowntime Data set

# %%
df=pd.read_csv('MachineDowntime.csv')

# %%
# Glance the dataframe

# %%
df.head()
# Out:
#          Date            Machine_ID Assembly_Line_No  Hydraulic_Pressure  \
# 0  31-12-2021  Makino-L1-Unit1-2013     Shopfloor-L1               71.04
# 1  31-12-2021  Makino-L1-Unit1-2013     Shopfloor-L1              125.33
# 2  31-12-2021  Makino-L3-Unit1-2015     Shopfloor-L3               71.12
# 3  31-05-2022  Makino-L2-Unit1-2015     Shopfloor-L2              139.34
# 4  31-03-2022  Makino-L1-Unit1-2013     Shopfloor-L1               60.51
#
#    Coolant_Pressure  Air_System_Pressure  Coolant_Temperature  \
# 0          6.933725             6.284965                 25.6
# 1          4.936892             6.196733                 35.3
# 2          6.839413             6.655448                 13.1
# 3          4.574382             6.560394                 24.4
# 4          6.893182             6.141238                  4.1
#
#    Hydraulic_Oil_Temperature  Spindle_Bearing_Temperature  Spindle_Vibration  \
# ...

# %%
# Find the columns names

# %%
df.columns
# Out:
# Index(['Date', 'Machine_ID', 'Assembly_Line_No', 'Hydraulic_Pressure',
#        'Coolant_Pressure', 'Air_System_Pressure', 'Coolant_Temperature',
#        'Hydraulic_Oil_Temperature', 'Spindle_Bearing_Temperature',
#        'Spindle_Vibration', 'Tool_Vibration', 'Spindle_Speed', 'Voltage',
#        'Torque', 'Cutting', 'Downtime'],
#       dtype='object')

# %%
# Check the Shape of Data Frame

# %%
df.shape
# in this dataframe 2500 rows and 16 columns
# Out:
# (2500, 16)

# %%
# To check the datatype of columns

# %%
df.info()
# Date, Machine_ID, Assembly_Line_No,Downtime (Categorical variable)
'''  Hydraulic_Pressure(numerical variable),
Coolant_Pressure(numerical variable),
Air_System_Pressure(numerical variable),
Coolant_Temperature(numerical variable),
Hydraulic_Oil_Temperature(numerical variable),
Spindle_Bearing_Temperature(numerical variable),
Spindle_Vibration(numerical variable),
Tool_Vibration(numerical variable),
Spindle_Speed(numerical variable),
Voltage(numerical variable),
Torque(numerical variable),
Cutting(numerical variable) ''' #(Numerical Variable)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Date                         2500 non-null   object
#  1   Machine_ID                   2500 non-null   object
#  2   Assembly_Line_No             2500 non-null   object
#  3   Hydraulic_Pressure           2490 non-null   float64
#  4   Coolant_Pressure             2481 non-null   float64
#  5   Air_System_Pressure          2483 non-null   float64
#  6   Coolant_Temperature          2488 non-null   float64
#  7   Hydraulic_Oil_Temperature    2484 non-null   float64
#  8   Spindle_Bearing_Temperature  2493 non-null   float64
#  9   Spindle_Vibration            2489 non-null   float64
#  10  Tool_Vibration               2489 non-null   float64
#  11  Spindle_Speed                2494 non-null   float64
# ...

# %%
# Query to Check Statistical information

# %%
df.describe()
# Out:
#        Hydraulic_Pressure  Coolant_Pressure  Air_System_Pressure  \
# count         2490.000000       2481.000000          2483.000000
# mean           101.409084          4.947058             6.499275
# std             30.289301          0.997357             0.407279
# min            -14.326454          0.325000             5.063480
# 25%             76.355000          4.462464             6.217987
# 50%             96.763486          4.939960             6.505191
# 75%            126.415727          5.518401             6.780550
# max            191.000000         11.350000             7.973992
#
#        Coolant_Temperature  Hydraulic_Oil_Temperature  \
# count          2488.000000                2484.000000
# mean             18.559887                  47.618317
# std               8.554480                   3.768674
# min               4.100000                  35.200000
# 25%              10.400000                  45.100000
# ...

# %%
# Scatter plot between Hydraulic_Pressure and Coolant_Pressure
plt.figure(figsize=(8, 6))
sns.scatterplot(x=df['Hydraulic_Pressure'], y=df['Coolant_Pressure'],hue=df['Assembly_Line_No'], data=df)
plt.title('Scatter Plot: Hydraulic Pressure vs Coolant Pressure')
plt.xlabel('Hydraulic Pressure')
plt.ylabel('Coolant Pressure')
plt.show()

# %%
import plotly.graph_objects as go

scatter_plot = go.Scatter(x=df['Hydraulic_Pressure'], y=df['Coolant_Pressure'], mode='markers',
                          marker=dict(color='blue', size=8),
                          name='Scatter Plot: Hydraulic Pressure vs Coolant Pressure')

layout = go.Layout(title='Scatter Plot: Hydraulic Pressure vs Coolant Pressure',
                   xaxis=dict(title='Hydraulic Pressure'),
                   yaxis=dict(title='Coolant Pressure'))

fig = go.Figure(data=[scatter_plot], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Line plot of Spindle_Speed over Date
plt.figure(figsize=(15, 5))
sns.lineplot(x='Date', y='Spindle_Speed', data=df.head(700))
plt.title('Line Plot: Spindle Speed over Time')
plt.xlabel('Date')
plt.ylabel('Spindle Speed')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.show()

# %%
line_plot = go.Scatter(x=df['Date'], y=df['Spindle_Speed'], mode='lines',
                       marker=dict(color='green'),
                       name='Line Plot: Spindle Speed over Time')

layout = go.Layout(title='Line Plot: Spindle Speed over Time',
                   xaxis=dict(title='Date'),
                   yaxis=dict(title='Spindle Speed'))

fig = go.Figure(data=[line_plot], layout=layout)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Bar plot of Assembly_Line_No
colors = ["#1f77b4", "#ff7f0e", "#2ca02c"]
plt.figure(figsize=(5, 3))
sns.countplot(x='Assembly_Line_No',palette=colors, data=df)
plt.title('Bar Plot: Assembly Line Counts')
plt.xlabel('Assembly Line Number')
plt.ylabel('Count')
plt.show()
# Out:
# <ipython-input-17-0eec09f841b9>:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Assembly_Line_No',palette=colors, data=df)

# %%
import plotly.express as px

bar_plot = px.bar(df['Assembly_Line_No'].value_counts(), x=df['Assembly_Line_No'].value_counts().index,
                  y=df['Assembly_Line_No'].value_counts(),
                  labels={'x': 'Assembly Line Number', 'y': 'Count'},
                  title='Bar Plot: Assembly Line Counts')

bar_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Histogram of Coolant_Temperature
plt.figure(figsize=(8, 3))
sns.histplot(df['Coolant_Temperature'], bins=20, kde=True, color='orange')
plt.title('Histogram: Coolant Temperature Distribution')
plt.xlabel('Coolant Temperature')
plt.ylabel('Frequency')
plt.show()

# %%
histogram = px.histogram(df, x='Coolant_Temperature', nbins=20,
                         labels={'x': 'Coolant Temperature', 'y': 'Frequency'},
                         title='Histogram: Coolant Temperature Distribution')

histogram.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# DATA PREPROCESSING

# %%
# Check The null value

# %%
df.isnull().sum()
# As per the data we get Hydraulic_Pressure has 10 null value
# Coolant_Pressure has 19, Air_System_Pressure has 17, Coolant_Temperature has 12,Hydraulic_Oil_Temperature has 16
# Spindle_Bearing_Temperature has 7,Spindle_Vibration has 11,Tool_Vibration  has 11,Spindle_Speed has 6
# Voltage has 6, Torque has 21, Cutting has 7
# Out:
# Date                            0
# Machine_ID                      0
# Assembly_Line_No                0
# Hydraulic_Pressure             10
# Coolant_Pressure               19
# Air_System_Pressure            17
# Coolant_Temperature            12
# Hydraulic_Oil_Temperature      16
# Spindle_Bearing_Temperature     7
# Spindle_Vibration              11
# Tool_Vibration                 11
# Spindle_Speed                   6
# Voltage                         6
# Torque                         21
# Cutting                         7
# Downtime                        0
# dtype: int64

# %%
# create Copy of a DF

# %%
dfc=df.copy()
dfc.head()
# Out:
#          Date            Machine_ID Assembly_Line_No  Hydraulic_Pressure  \
# 0  31-12-2021  Makino-L1-Unit1-2013     Shopfloor-L1               71.04
# 1  31-12-2021  Makino-L1-Unit1-2013     Shopfloor-L1              125.33
# 2  31-12-2021  Makino-L3-Unit1-2015     Shopfloor-L3               71.12
# 3  31-05-2022  Makino-L2-Unit1-2015     Shopfloor-L2              139.34
# 4  31-03-2022  Makino-L1-Unit1-2013     Shopfloor-L1               60.51
#
#    Coolant_Pressure  Air_System_Pressure  Coolant_Temperature  \
# 0          6.933725             6.284965                 25.6
# 1          4.936892             6.196733                 35.3
# 2          6.839413             6.655448                 13.1
# 3          4.574382             6.560394                 24.4
# 4          6.893182             6.141238                  4.1
#
#    Hydraulic_Oil_Temperature  Spindle_Bearing_Temperature  Spindle_Vibration  \
# ...

# %%
# Query to check categorical columns

# %%
dfc.select_dtypes(include='object').head()
# Out:
#          Date            Machine_ID Assembly_Line_No         Downtime
# 0  31-12-2021  Makino-L1-Unit1-2013     Shopfloor-L1  Machine_Failure
# 1  31-12-2021  Makino-L1-Unit1-2013     Shopfloor-L1  Machine_Failure
# 2  31-12-2021  Makino-L3-Unit1-2015     Shopfloor-L3  Machine_Failure
# 3  31-05-2022  Makino-L2-Unit1-2015     Shopfloor-L2  Machine_Failure
# 4  31-03-2022  Makino-L1-Unit1-2013     Shopfloor-L1  Machine_Failure

# %%
# Query to check Numerical Columns

# %%
dfc.select_dtypes(exclude='object').head()
# Out:
#    Hydraulic_Pressure  Coolant_Pressure  Air_System_Pressure  \
# 0               71.04          6.933725             6.284965
# 1              125.33          4.936892             6.196733
# 2               71.12          6.839413             6.655448
# 3              139.34          4.574382             6.560394
# 4               60.51          6.893182             6.141238
#
#    Coolant_Temperature  Hydraulic_Oil_Temperature  \
# 0                 25.6                       46.0
# 1                 35.3                       47.4
# 2                 13.1                       40.7
# 3                 24.4                       44.2
# 4                  4.1                       47.3
#
#    Spindle_Bearing_Temperature  Spindle_Vibration  Tool_Vibration  \
# 0                         33.4              1.291          26.492
# 1                         34.6              1.382          25.274
# 2                         33.0              1.319          30.608
# ...

# %%
# Check outliers for missing columns value [Hydraulic_Pressure]
# We use Box plot to check outliers

# %%
sns.boxplot(dfc['Hydraulic_Pressure'])
# Out:
# <Axes: ylabel='Hydraulic_Pressure'>

# %%
# Handling Missing values
# to handel missing values we use two technique 1) univarient imputation technique (mean, mode, median)
# 2) multi varient imputation technique (MICE, KNN)

# %%
# Mean & Median for Hydraulic_Pressure

# %%
mean_Hydraulic_Pressure=dfc['Hydraulic_Pressure'].mean()
mean_Hydraulic_Pressure
# Out:
# 101.40908377755423

# %%
Median_Hydraulic_Pressure= dfc['Hydraulic_Pressure'].median()
Median_Hydraulic_Pressure
# Out:
# 96.7634864

# %%
# we have outlier so here we use median to fill that missing values

# %%
dfc['Hydraulic_Pressure']=dfc['Hydraulic_Pressure'].fillna(Median_Hydraulic_Pressure)

# %%
dfc['Hydraulic_Pressure'].isnull().sum()
# Out:
# 0

# %%
# Check outliers for missing columns value [Coolant_Pressure]
# We use Box plot to check outliers

# %%
sns.boxplot(dfc['Coolant_Pressure'])
# Out:
# <Axes: ylabel='Coolant_Pressure'>

# %%
# Mean & Median for Coolant_Pressure

# %%
mean_Coolant_Pressure=dfc['Coolant_Pressure'].mean()

# %%
median_Coolant_Pressure=dfc['Coolant_Pressure'].median()

# %%
# we have outlier so here we use median to fill that missing values

# %%
dfc['Coolant_Pressure']=dfc['Coolant_Pressure'].fillna(median_Coolant_Pressure)

# %%
dfc['Hydraulic_Pressure'].isnull().sum()
# Out:
# 0

# %%
# Check outliers for missing columns value [Air_System_Pressure]
# We use Box plot to check outliers

# %%
sns.boxplot(dfc['Air_System_Pressure'])
# Out:
# <Axes: ylabel='Air_System_Pressure'>

# %%
# Mean & Median for Air_System_Pressure

# %%
Mean_Air_System_Pressure=dfc['Air_System_Pressure'].mean()

# %%
Median_Air_System_Pressure=dfc['Air_System_Pressure'].median()

# %%
# we have outlier so here we use median to fill that missing values

# %%
dfc['Air_System_Pressure']=dfc['Air_System_Pressure'].fillna(Median_Air_System_Pressure)

# %%
dfc['Air_System_Pressure'].isnull().sum()
# Out:
# 0

# %%
# Check outliers for missing columns value [Coolant_Temperature]
# We use Box plot to check outliers

# %%
sns.boxplot(dfc['Coolant_Temperature'])
# Out:
# <Axes: ylabel='Coolant_Temperature'>

# %%
# Mean & Median for Coolant_Temperature

# %%
Mean_Coolant_Temperature=dfc['Coolant_Temperature'].mean()

# %%
Median_Coolant_Temperature=dfc['Coolant_Temperature'].median()

# %%
# we have outlier so here we use median to fill that missing values

# %%
dfc['Coolant_Temperature']=dfc['Coolant_Temperature'].fillna(Median_Coolant_Temperature)

# %%
dfc['Coolant_Temperature'].isnull().sum()
# Out:
# 0

# %%
# Check outliers for missing columns value [Hydraulic_Oil_Temperature ]
# We use Box plot to check outliers

# %%
sns.boxplot(dfc['Hydraulic_Oil_Temperature'])
# Out:
# <Axes: ylabel='Hydraulic_Oil_Temperature'>

# %%
# Mean & Median for Coolant_Temperature Hydraulic_Oil_Temperature

# %%
Mean_Hydraulic_Oil_Temperature=dfc['Hydraulic_Oil_Temperature'].mean()

# %%
Median_Hydraulic_Oil_Temperature=dfc['Hydraulic_Oil_Temperature'].median()

# %%
# we have outlier so here we use median to fill that missing values

# %%
dfc['Hydraulic_Oil_Temperature']=dfc['Hydraulic_Oil_Temperature'].fillna(Median_Hydraulic_Oil_Temperature)

# %%
dfc['Hydraulic_Oil_Temperature'].isnull().sum()
# Out:
# 0

# %%
# Check outliers for missing columns value [Spindle_Bearing_Temperature]
# We use Box plot to check outliers

# %%
sns.boxplot(dfc['Spindle_Bearing_Temperature'])
# Out:
# <Axes: ylabel='Spindle_Bearing_Temperature'>

# %%
# Mean & Median for Coolant_Temperature Spindle_Bearing_Temperature

# %%
Mean_Spindle_Bearing_Temperature=dfc['Spindle_Bearing_Temperature'].mean()

# %%
Median_Spindle_Bearing_Temperature=dfc['Spindle_Bearing_Temperature'].median()

# %%
# we have outlier so here we use median to fill that missing values

# %%
dfc['Spindle_Bearing_Temperature']=dfc['Spindle_Bearing_Temperature'].fillna(Median_Spindle_Bearing_Temperature)

# %%
dfc['Spindle_Bearing_Temperature'].isnull().sum()
# Out:
# 0

# %%
# Check outliers for missing columns value [Spindle_Vibration]
# We use Box plot to check outliers

# %%
sns.boxplot(dfc['Spindle_Vibration'])
# Out:
# <Axes: ylabel='Spindle_Vibration'>

# %%
# Mean & Median for Coolant_Temperature Spindle_Vibration

# %%
Mean_Spindle_Vibration=dfc['Spindle_Vibration'].mean()

# %%
Median_Spindle_Vibration=dfc['Spindle_Vibration'].median()

# %%
# we have outlier so here we use median to fill that missing values

# %%
dfc['Spindle_Vibration']=dfc['Spindle_Vibration'].fillna(Median_Spindle_Vibration)

# %%
dfc['Spindle_Vibration'].isnull().sum()
# Out:
# 0

# %%
# Check outliers for missing columns value [Tool_Vibration]
# We use Box plot to check outliers

# %%
sns.boxplot(dfc['Tool_Vibration'])
# Out:
# <Axes: ylabel='Tool_Vibration'>

# %%
# Mean & Median for Tool_Vibration

# %%
Mean_Tool_Vibration=dfc['Tool_Vibration'].mean()

# %%
Median_Tool_Vibration=dfc['Tool_Vibration'].median()

# %%
# we have outlier so here we use median to fill that missing values

# %%
dfc['Tool_Vibration']=dfc['Tool_Vibration'].fillna(Median_Tool_Vibration)

# %%
dfc['Tool_Vibration'].isnull().sum()
# Out:
# 0

# %%
# Check outliers for missing columns value [Spindle_Speed]
# We use Box plot to check outliers

# %%
sns.boxplot(dfc['Spindle_Speed'])
# Out:
# <Axes: ylabel='Spindle_Speed'>

# %%
# Mean & Median for Spindle_Speed

# %%
Mean_Spindle_Speed=dfc['Spindle_Speed'].mean()

# %%
Median_Spindle_Speed=dfc['Spindle_Speed'].median()

# %%
# we have outlier so here we use median to fill that missing values

# %%
dfc['Spindle_Speed']=dfc['Spindle_Speed'].fillna(Median_Spindle_Speed)

# %%
dfc['Spindle_Speed'].isnull().sum()
# Out:
# 0

# %%
# Check outliers for missing columns value [Voltage]
# We use Box plot to check outliers

# %%
sns.boxplot(dfc['Voltage'])
# Out:
# <Axes: ylabel='Voltage'>

# %%
# Mean & Median for Spindle_Speed

# %%
Mean_Voltage=dfc['Voltage'].mean()

# %%
Median_Voltage=dfc['Voltage'].median()

# %%
# we have outlier so here we use median to fill that missing values

# %%
dfc['Voltage']=dfc['Voltage'].fillna(Median_Voltage)

# %%
dfc['Voltage'].isnull().sum()
# Out:
# 0

# %%
# Check outliers for missing columns value [Torque]
# We use Box plot to check outliers

# %%
sns.boxplot(dfc['Torque'])
# Out:
# <Axes: ylabel='Torque'>

# %%
# Mean & Median for Torque

# %%
Mean_Torque=dfc['Torque'].mean()

# %%
Median_Torque=dfc['Torque'].median()

# %%
# we have outlier so here we use median to fill that missing values

# %%
dfc['Torque']=dfc['Torque'].fillna(Median_Torque)

# %%
dfc['Torque'].isnull().sum()
# Out:
# 0

# %%
# Check outliers for missing columns value [Cutting]
# We use Box plot to check outliers

# %%
sns.boxplot(dfc['Cutting'])
# Out:
# <Axes: ylabel='Cutting'>

# %%
# Mean & Median for Cutting

# %%
Mean_Cutting=dfc['Cutting'].mean()

# %%
Median_Cutting=dfc['Cutting'].median()

# %%
# we have no outlier so here we use mean to fill that missing values

# %%
dfc['Cutting']=dfc['Cutting'].fillna(Mean_Cutting)

# %%
dfc['Cutting'].isnull().sum()
# Out:
# 0

# %%
# Read the Data from dataFrame

# %%
dfc.head()
# Out:
#          Date            Machine_ID Assembly_Line_No  Hydraulic_Pressure  \
# 0  31-12-2021  Makino-L1-Unit1-2013     Shopfloor-L1               71.04
# 1  31-12-2021  Makino-L1-Unit1-2013     Shopfloor-L1              125.33
# 2  31-12-2021  Makino-L3-Unit1-2015     Shopfloor-L3               71.12
# 3  31-05-2022  Makino-L2-Unit1-2015     Shopfloor-L2              139.34
# 4  31-03-2022  Makino-L1-Unit1-2013     Shopfloor-L1               60.51
#
#    Coolant_Pressure  Air_System_Pressure  Coolant_Temperature  \
# 0          6.933725             6.284965                 25.6
# 1          4.936892             6.196733                 35.3
# 2          6.839413             6.655448                 13.1
# 3          4.574382             6.560394                 24.4
# 4          6.893182             6.141238                  4.1
#
#    Hydraulic_Oil_Temperature  Spindle_Bearing_Temperature  Spindle_Vibration  \
# ...

# %%
# Check the null value

# %%
dfc.isnull().sum()
# Finally i fixed all null value next we do encoding
# Out:
# Date                           0
# Machine_ID                     0
# Assembly_Line_No               0
# Hydraulic_Pressure             0
# Coolant_Pressure               0
# Air_System_Pressure            0
# Coolant_Temperature            0
# Hydraulic_Oil_Temperature      0
# Spindle_Bearing_Temperature    0
# Spindle_Vibration              0
# Tool_Vibration                 0
# Spindle_Speed                  0
# Voltage                        0
# Torque                         0
# Cutting                        0
# Downtime                       0
# dtype: int64

# %%
# capping the outlier

# %%
# Find the statistical Information:-

# %%
dfc.describe()
# Out:
#        Hydraulic_Pressure  Coolant_Pressure  Air_System_Pressure  \
# count         2500.000000       2500.000000          2500.000000
# mean           101.390501          4.947005             6.499315
# std             30.230060          0.993559             0.405892
# min            -14.326454          0.325000             5.063480
# 25%             76.470719          4.466685             6.220267
# 50%             96.763486          4.939960             6.505191
# 75%            126.301071          5.512482             6.779330
# max            191.000000         11.350000             7.973992
#
#        Coolant_Temperature  Hydraulic_Oil_Temperature  \
# count          2500.000000                2500.000000
# mean             18.572560                  47.618840
# std               8.535867                   3.756596
# min               4.100000                  35.200000
# 25%              10.475000                  45.100000
# ...

# %%
# Capping the outlier of column Hydraulic_Pressure

# %%
# Find q1
Q1=dfc.describe()['Hydraulic_Pressure']['25%']
Q1
# Out:
# 76.470718575

# %%
# Find Q3
Q3=dfc.describe()['Hydraulic_Pressure']['75%']
Q3
# Out:
# 126.30107115

# %%
# Find IQR
IQR=Q3-Q1
IQR
# Out:
# 49.83035257499999

# %%
# Find Lower Limit
L_L=Q1-1.5*IQR
U_L=Q3+1.5*IQR

# %%
# Apply Capping technique to Fixed

# %%
dfc['Hydraulic_Pressure']=dfc['Hydraulic_Pressure'].clip(L_L,U_L)

# %%
# Check Outliers

# %%
sns.boxplot(dfc['Hydraulic_Pressure'])
# Out:
# <Axes: ylabel='Hydraulic_Pressure'>

# %%
# Capping the outlier of column Coolant_Pressure

# %%
Q1=dfc.describe()['Coolant_Pressure']['25%']
Q3=dfc.describe()['Coolant_Pressure']['75%']

# %%
IQR=Q3-Q1
IQR
# Out:
# 1.04579701875

# %%
L_L=Q1-1.5*IQR
U_L=Q3+1.5*IQR

# %%
# Apply Capping Technique To Fixed

# %%
dfc['Coolant_Pressure']=dfc['Coolant_Pressure'].clip(L_L,U_L)

# %%
# Check Outliers
sns.boxplot(dfc['Coolant_Pressure'])
# Out:
# <Axes: ylabel='Coolant_Pressure'>

# %%
# Capping the outlier of column Air_System_Pressure

# %%
Q1=dfc.describe()['Air_System_Pressure']['25%']
Q3=dfc.describe()['Air_System_Pressure']['75%']

# %%
IQR=Q3-Q1
IQR
# Out:
# 0.5590634505000001

# %%
L_L=Q1-1.5*IQR
U_L=Q3+1.5*IQR

# %%
# Apply Capping Technique To Fixed

# %%
dfc['Air_System_Pressure']=dfc['Air_System_Pressure'].clip(L_L,U_L)

# %%
# Check Outliers
sns.boxplot(dfc['Air_System_Pressure'])
# Out:
# <Axes: ylabel='Air_System_Pressure'>

# %%
# Capping the outlier of column Hydraulic_Oil_Temperature

# %%
Q1=dfc.describe()['Hydraulic_Oil_Temperature']['25%']
Q3=dfc.describe()['Hydraulic_Oil_Temperature']['75%']
IQR= Q3-Q1
IQR
# Out:
# 5.0

# %%
L_L=Q1-1.5*IQR
U_L=Q3+1.5*IQR

# %%
# Apply Capping Technique To Fixed

# %%
dfc['Hydraulic_Oil_Temperature']=dfc['Hydraulic_Oil_Temperature'].clip(L_L,U_L)

# %%
# Check Outliers
sns.boxplot(dfc['Hydraulic_Oil_Temperature'])
# Out:
# <Axes: ylabel='Hydraulic_Oil_Temperature'>

# %%
# Capping the outlier of column Spindle_Bearing_Temperature

# %%
Q1=dfc.describe()['Spindle_Bearing_Temperature']['25%']
Q3=dfc.describe()['Spindle_Bearing_Temperature']['75%']
IQR=Q3-Q1
IQR
# Out:
# 5.100000000000001

# %%
L_L=Q1-1.5*IQR
U_L=Q3+1.5*IQR

# %%
# Apply Capping Technique To Fixed

# %%
dfc['Spindle_Bearing_Temperature']=dfc['Spindle_Bearing_Temperature'].clip(L_L,U_L)

# %%
# Check Outliers

# %%
sns.boxplot(dfc['Spindle_Bearing_Temperature'])
# Out:
# <Axes: ylabel='Spindle_Bearing_Temperature'>

# %%
# Capping the outlier of column Spindle_Vibration

# %%
Q1=dfc.describe()['Spindle_Vibration']['25%']
Q3=dfc.describe()['Spindle_Vibration']['75%']
IQR=Q3-Q1
IQR
# Out:
# 0.4555

# %%
L_L=Q1-1.5*IQR
U_L=Q3+1.5*IQR

# %%
# Apply Capping Technique To Fixed

# %%
dfc['Spindle_Vibration']=dfc['Spindle_Vibration'].clip(L_L,U_L)

# %%
# Check Outliers
sns.boxplot(dfc['Spindle_Vibration'])
# Out:
# <Axes: ylabel='Spindle_Vibration'>

# %%
# Capping the outlier of column Tool_Vibration

# %%
Q1=dfc.describe()['Tool_Vibration']['25%']
Q3=dfc.describe()['Tool_Vibration']['75%']
IQR=Q3-Q1

# %%
L_L=Q1-1.5*IQR
U_L=Q3+1.5*IQR

# %%
# Apply Capping Technique To Fixed

# %%
dfc['Tool_Vibration']=dfc['Tool_Vibration'].clip(L_L,U_L)

# %%
#Check Outliers

# %%
sns.boxplot(dfc['Tool_Vibration'])
# Out:
# <Axes: ylabel='Tool_Vibration'>

# %%
# Capping the outlier of column Spindle_Speed

# %%
Q1=dfc.describe()['Spindle_Speed']['25%']
Q3=dfc.describe()['Spindle_Speed']['75%']
IQR=Q3-Q1
IQR
# Out:
# 4570.75

# %%
L_L=Q1-1.5*IQR
U_L=Q3+1.5*IQR

# %%
# Apply Capping Technique To Fixed

# %%
dfc['Spindle_Speed']=dfc['Spindle_Speed'].clip(L_L,U_L)

# %%
# Check Outliers
sns.boxplot(dfc['Spindle_Speed'])
# Out:
# <Axes: ylabel='Spindle_Speed'>

# %%
# Capping the outlier of column Voltage

# %%
Q1=dfc.describe()['Voltage']['25%']
Q3=dfc.describe()['Voltage']['75%']
IQR=Q3-Q1

# %%
L_L=Q1-1.5*IQR
U_L=Q3+1.5*IQR

# %%
# Apply Capping Technique To Fixed

# %%
dfc['Voltage']=dfc['Voltage'].clip(L_L,U_L)

# %%
# Check Outliers
sns.boxplot(dfc['Voltage'])
# Out:
# <Axes: ylabel='Voltage'>

# %%
# Capping the outlier of column Torque

# %%
Q1=dfc.describe()['Torque']['25%']
Q3=dfc.describe()['Torque']['75%']
IQR=Q3-Q1
L_L=Q1-1.5*IQR
U_L=Q3+1.5*IQR

# %%
# Apply Capping Technique To Fixed

# %%
dfc['Torque']=dfc['Torque'].clip(L_L,U_L)

# %%
# Check Outliers

# %%
sns.boxplot(dfc['Torque'])
# Out:
# <Axes: ylabel='Torque'>

# %%
dfc.head()
# Out:
#          Date            Machine_ID Assembly_Line_No  Hydraulic_Pressure  \
# 0  31-12-2021  Makino-L1-Unit1-2013     Shopfloor-L1               71.04
# 1  31-12-2021  Makino-L1-Unit1-2013     Shopfloor-L1              125.33
# 2  31-12-2021  Makino-L3-Unit1-2015     Shopfloor-L3               71.12
# 3  31-05-2022  Makino-L2-Unit1-2015     Shopfloor-L2              139.34
# 4  31-03-2022  Makino-L1-Unit1-2013     Shopfloor-L1               60.51
#
#    Coolant_Pressure  Air_System_Pressure  Coolant_Temperature  \
# 0          6.933725             6.284965                 25.6
# 1          4.936892             6.196733                 35.3
# 2          6.839413             6.655448                 13.1
# 3          4.574382             6.560394                 24.4
# 4          6.893182             6.141238                  4.1
#
#    Hydraulic_Oil_Temperature  Spindle_Bearing_Temperature  Spindle_Vibration  \
# ...

# %%
# seprate Categorical Variable
dfc.select_dtypes(include='object')
# Out:
#             Date            Machine_ID Assembly_Line_No            Downtime
# 0     31-12-2021  Makino-L1-Unit1-2013     Shopfloor-L1     Machine_Failure
# 1     31-12-2021  Makino-L1-Unit1-2013     Shopfloor-L1     Machine_Failure
# 2     31-12-2021  Makino-L3-Unit1-2015     Shopfloor-L3     Machine_Failure
# 3     31-05-2022  Makino-L2-Unit1-2015     Shopfloor-L2     Machine_Failure
# 4     31-03-2022  Makino-L1-Unit1-2013     Shopfloor-L1     Machine_Failure
# ...          ...                   ...              ...                 ...
# 2495  01-02-2022  Makino-L1-Unit1-2013     Shopfloor-L1  No_Machine_Failure
# 2496  01-02-2022  Makino-L1-Unit1-2013     Shopfloor-L1  No_Machine_Failure
# 2497  01-02-2022  Makino-L2-Unit1-2015     Shopfloor-L2  No_Machine_Failure
# 2498  01-02-2022  Makino-L3-Unit1-2015     Shopfloor-L3  No_Machine_Failure
# 2499  01-02-2022  Makino-L2-Unit1-2015     Shopfloor-L2     Machine_Failure
#
# [2500 rows x 4 columns]

# %%
# ENCODING

# %%
# Convert Categorical or text data to Numerical

# %%
# there are two types of encoding
# 1) Nominal Encoding: Date,Machin_ID,Downtime
# 2) Ordinal Encoding: Assembly_Line_No

# %%
# Nominal Encoding
dfc=pd.get_dummies(dfc,columns=['Date','Machine_ID','Downtime'],drop_first=True)

# %%
dfc.head()
# Out:
#   Assembly_Line_No  Hydraulic_Pressure  Coolant_Pressure  Air_System_Pressure  \
# 0     Shopfloor-L1               71.04          6.933725             6.284965
# 1     Shopfloor-L1              125.33          4.936892             6.196733
# 2     Shopfloor-L3               71.12          6.839413             6.655448
# 3     Shopfloor-L2              139.34          4.574382             6.560394
# 4     Shopfloor-L1               60.51          6.893182             6.141238
#
#    Coolant_Temperature  Hydraulic_Oil_Temperature  \
# 0                 25.6                       46.0
# 1                 35.3                       47.4
# 2                 13.1                       40.7
# 3                 24.4                       44.2
# 4                  4.1                       47.3
#
#    Spindle_Bearing_Temperature  Spindle_Vibration  Tool_Vibration  \
# 0                         33.4              1.291          26.492
# ...

# %%
# Check Distribution of Numerical Columns

# %%
plt.figure(figsize=(15,7))
plt.subplot(3,3,1)
sns.histplot(dfc['Hydraulic_Pressure'],color='g')
plt.subplot(3,3,2)
sns.histplot(dfc['Coolant_Pressure'],color='r')
plt.subplot(3,3,3)
sns.histplot(dfc['Air_System_Pressure'],color='b')
plt.subplot(3,3,4)
sns.histplot(dfc['Coolant_Temperature'],color='g')
plt.subplot(3,3,5)
sns.histplot(dfc['Hydraulic_Oil_Temperature'],color='r')
plt.subplot(3,3,6)
sns.histplot(dfc['Spindle_Bearing_Temperature'],color='b')
plt.subplot(3,3,7)
sns.histplot(dfc['Spindle_Vibration'],color='g')
plt.subplot(3,3,8)
sns.histplot(dfc['Tool_Vibration'],color='r')
plt.subplot(3,3,9)
sns.histplot(dfc['Spindle_Speed'],color='b')
# Normally Distributed
# Out:
# <Axes: xlabel='Spindle_Speed', ylabel='Count'>

# %%
# Ordinal Encoding

# %%
dfc['Assembly_Line_No'].value_counts()
# Out:
# Shopfloor-L1    874
# Shopfloor-L3    818
# Shopfloor-L2    808
# Name: Assembly_Line_No, dtype: int64

# %%
sf={'Shopfloor-L1':1,'Shopfloor-L2':2,'Shopfloor-L3':3}

# %%
dfc['Assembly_Line_No']=dfc['Assembly_Line_No'].str.strip()

# %%
dfc['Assembly_Line_No']=dfc['Assembly_Line_No'].map(sf)

# %%
dfc.head()
# Out:
#    Assembly_Line_No  Hydraulic_Pressure  Coolant_Pressure  \
# 0                 1               71.04          6.933725
# 1                 1              125.33          4.936892
# 2                 3               71.12          6.839413
# 3                 2              139.34          4.574382
# 4                 1               60.51          6.893182
#
#    Air_System_Pressure  Coolant_Temperature  Hydraulic_Oil_Temperature  \
# 0             6.284965                 25.6                       46.0
# 1             6.196733                 35.3                       47.4
# 2             6.655448                 13.1                       40.7
# 3             6.560394                 24.4                       44.2
# 4             6.141238                  4.1                       47.3
#
#    Spindle_Bearing_Temperature  Spindle_Vibration  Tool_Vibration  \
# 0                         33.4              1.291          26.492
# ...
